# %%
import pandas as pd
import numpy as np
import sys

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = "/Users/flo/Desktop/MSAN/MSAN622/MSAN622/Homework3/"

# %%
data=pd.read_csv(filepath+'Seatbelts.csv')
print "data loaded"
print data.shape
# Out:
# data loaded
# (192, 9)

# %%
data
# Out:
#      DriversKilled  drivers  front  rear    kms  PetrolPrice  VanKilled  law  \
# 0              107     1687    867   269   9059     0.102972         12    0
# 1               97     1508    825   265   7685     0.102363          6    0
# 2              102     1507    806   319   9963     0.102062         12    0
# 3               87     1385    814   407  10955     0.100873          8    0
# 4              119     1632    991   454  11823     0.101020         10    0
# 5              106     1511    945   427  12391     0.100581         13    0
# 6              110     1559   1004   522  13460     0.103774         11    0
# 7              106     1630   1091   536  14055     0.104076          6    0
# 8              107     1579    958   405  12106     0.103774         10    0
# 9              134     1653    850   437  11372     0.103026         16    0
# 10             147     2152   1109   434   9834     0.102730         13    0
# ...

# %%
test = data.time.str.split("-")

# %%
ts = pd.Series(data.PetrolPrice, index=data.time)

# %%
ts.plot()
